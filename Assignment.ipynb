# %%
import pandas as pd 
import numpy as np
data=pd.read_csv('D:\\Knight internship assignmen\\Data\\train.csv')
data
# Out:
#            user_name    country  \
# 0                NaN  Australia
# 1      @wawinereport         US
# 2                NaN      Italy
# 3         @vossroger     France
# 4         @vossroger     France
# ...              ...        ...
# 82652    @wineschach      Spain
# 82653            NaN         US
# 82654     @vossroger     France
# 82655     @vossroger     France
# 82656            NaN         US
#
#                                             review_title  \
# 0      Andrew Peace 2007 Peace Family Vineyard Chardo...
# 1      North by Northwest 2014 Red (Columbia Valley (...
# 2                      Renato Ratti 2007 Conca  (Barolo)
# 3      Domaine l'Ancienne Cure 2010 L'Abbaye White (B...
# 4      Château du Cèdre 2012 Le Cèdre Vintage Malbec ...
# ...                                                  ...
# 82652                   Montecillo 2007 Crianza  (Rioja)
# 82653  Vivác Winery 2008 Single Vineyard Cabernet Sau...
# ...

# %%
sd=data.dropna()
sd
# Out:
#               user_name country  \
# 6         @wawinereport      US
# 7               @vboone      US
# 8           @paulgwine       US
# 10              @vboone      US
# 34          @paulgwine       US
# ...                 ...     ...
# 82630           @vboone      US
# 82632           @vboone      US
# 82639       @paulgwine       US
# 82641  @gordone_cellars      US
# 82642           @vboone      US
#
#                                             review_title  \
# 6      Gordon Estate 2012 Tradition Red (Columbia Val...
# 7      Rock Wall 2014 Monte Rosso Reserve Zinfandel (...
# 8      Elizabeth Chambers 2014 Falcon Glen Vineyard P...
# 10     Cuvaison 2014 Estate Grown Sauvignon Blanc (Ca...
# 34           Durant 2013 Raven Chardonnay (Dundee Hills)
# ...                                                  ...
# 82630  Yorkville Cellars 2010 Randle Hill Vineyard Sa...
# 82632            un4seen 2009 Red blend Red (California)
# ...

# %%
import matplotlib.pyplot as plt
sur=data["variety"].value_counts()
sur
fig, ax = plt.subplots(figsize=(40, 40)) 
ind = np.arange(len(sur.values)) 
ax.set_xticks(ind)
ax.set_xticklabels(sur.index, minor=False, size=40,rotation=90)
plt.bar(sur.index,sur.values,width=.7)

plt.show()

# %%
import seaborn as sns

tk=sd.groupby('user_name')['designation'].count().sort_values(ascending=True)
tk
sns.distplot(tk,rug=True,kde=True)
plt.title('Designation',size=20)
plt.show()

# %%
tur=sd["region_2"].value_counts()
tur
fig, ax = plt.subplots(figsize=(60, 40))
ind = np.arange(len(tur.values))
ax.set_xticks(ind)
ax.set_xticklabels(tur.index, minor=False, size=40,rotation=90)
plt.scatter(ind,tur.index,s=200)
plt.title("region_2",size=50)
plt.xlabel('x', size=50)
plt.ylabel('y',size=50)  
plt.show()

# %%
sur=sd["points"].value_counts()
sur
fig, ax = plt.subplots(figsize=(60, 40))
ind = np.arange(len(sur.values))
ax.set_xticks(ind)
ax.set_xticklabels(sur.index, minor=False, size=40,rotation=360)
plt.scatter(ind,sur.index,s=200)
plt.plot(ind,sur.index)
plt.title("Ratings",size=70)
plt.xlabel('x', size=50)
plt.ylabel('y',size=50)  
plt.show()

# %%
x=sd.loc[:,['review_title']]
y=sd.loc[:,['variety']]
x
y
# Out:
#                      variety
# 6                  Red Blend
# 7                  Zinfandel
# 8                 Pinot Noir
# 10           Sauvignon Blanc
# 34                Chardonnay
# ...                      ...
# 82630        Sauvignon Blanc
# 82632              Red Blend
# 82639             Pinot Noir
# 82641  Rhône-style Red Blend
# 82642             Pinot Noir
#
# [15986 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)
y
# Out:
# c:\users\hs999\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([15, 25, 14, ..., 14, 16, 14])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split (x, y, test_size = .20, random_state = 0)
print(X_train)
# Out:
#                                             review_title
# 27462  Coelho 2010 Estate Renovação Pinot Gris (Willa...
# 6102   Ryan Cochrane 2013 Solomon Hills Vineyard Char...
# 17646  Unum 2009 Reserve Cabernet Sauvignon (Spring M...
# 63648  Devil Proof 2012 Farrow Ranch Malbec (Alexande...
# 26363  Garré 2010 Private Reserve Merlot (Livermore V...
# ...                                                  ...
# 68179  Mike and Molly Hendry 2013 R.W. Moore Vineyard...
# 16713  Treos 2011 Founders Choice Estate Pinot Noir (...
# 51219  Adelsheim 2013 Caitlin's Reserve Chardonnay (W...
# 56200          McManis 2015 North Forty Red (California)
# 14276     Januik 2013 Reserve Red (Columbia Valley (WA))
#
# [12788 rows x 1 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
le=CountVectorizer()
x_train=le.fit_transform(X_train.iloc[:,0])



x_test=le.transform(X_test.iloc[:,0])



print(le.vocabulary_)
# Out:
# {'coelho': 1417, '2010': 60, 'estate': 2101, 'renovação': 4937, 'pinot': 4605, 'gris': 2646, 'willamette': 6505, 'valley': 6224, 'ryan': 5183, 'cochrane': 1414, '2013': 63, 'solomon': 5564, 'hills': 2832, 'vineyard': 6314, 'chardonnay': 1257, 'santa': 5246, 'maria': 3704, 'unum': 6194, '2009': 59, 'reserve': 4946, 'cabernet': 1031, 'sauvignon': 5264, 'spring': 5655, 'mountain': 4029, 'district': 1824, 'devil': 1777, 'proof': 4761, '2012': 62, 'farrow': 2188, 'ranch': 4859, 'malbec': 3663, 'alexander': 258, 'garré': 2480, 'private': 4747, 'merlot': 3839, 'livermore': 3487, 'breathless': 921, 'nv': 4224, 'ratafia': 4874, 'fortified': 2358, 'napa': 4092, 'parmeson': 4430, 'josephine': 3132, 'hill': 2828, 'russian': 5173, 'river': 5022, 'sineann': 5468, 'baby': 543, 'poux': 4695, 'columbia': 1438, 'wa': 6372, 'spicy': 5638, 'vines': 6313, '2016': 66, 'nouveau': 4203, 'noir': 4176, 'pagter': 4375, 'brothers': 957, 'lucky': 3566, 'club': 1399, 'white': 6476, 'hawk': 2745, 'syrah': 5856, 'y
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB().fit(x_train,y_train)


#print('predicted:',model.predict(titletest))   # output b
prediction=model.predict(x_test)
prediction
from sklearn.metrics import accuracy_score,confusion_matrix
print(accuracy_score(y_test,prediction))
print(confusion_matrix(y_test,prediction))
